# %%
import numpy as np

X = np.array([[0, 1, 0, 1], [1, 0, 1, 1], [0, 0, 0, 1], [1, 0, 1, 0]])

y = np.array([0, 1, 0, 1])

# %%
counts = {}
import numpy as np
for label in np.unique(y):
    counts[label] = X[y == label].sum(axis=0)
print("Частоты признаков:\n{}".format(counts))
# Out:
# Частоты признаков:
# {0: array([0, 1, 0, 2]), 1: array([2, 0, 2, 1])}

# %%
import mglearn
mglearn.plots.plot_animal_tree()

# %%
mglearn.plots.plot_tree_progressive()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
cancer.data, cancer.target, stratify=cancer.target, random_state=42)
tree = DecisionTreeClassifier(random_state=0)
tree.fit(X_train, y_train)
print("Правильность на обучающем наборе: {:.3f}".format(tree.score(X_train, y_train)))
print("Правильность на тестовом наборе: {:.3f}".format(tree.score(X_test, y_test)))
# Out:
# Правильность на обучающем наборе: 1.000
# Правильность на тестовом наборе: 0.937

# %%
tree = DecisionTreeClassifier(max_depth=4, random_state=0)
tree.fit(X_train, y_train)

print("Правильность на обучающем наборе: {:.3f}".format(tree.score(X_train, y_train)))
print("Правильность на тестовом наборе: {:.3f}".format(tree.score(X_test, y_test)))
# Out:
# Правильность на обучающем наборе: 0.988
# Правильность на тестовом наборе: 0.951

# %%
from sklearn.tree import export_graphviz

export_graphviz(tree, out_file="tree.dot", class_names=["malignant", "benign"], feature_names=cancer.feature_names, impurity=False, filled=True)

# %%
import graphviz

with open("tree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mglearn
# %matplotlib inline

from sklearn.model_selection import train_test_split 
from sklearn.datasets import load_breast_cancer 
from sklearn import tree
from sklearn.tree import export_graphviz
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
cancer.data, cancer.target, stratify=cancer.target, random_state=42)
clf = tree.DecisionTreeClassifier(max_depth=4, random_state=0)
clf = clf.fit(X_train, y_train)

import pydotplus
dot_data = tree.export_graphviz(clf, out_file=None)

# %%
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_pdf("cancer.pdf")
# Out:
# True

# %%
from IPython.display import Image
dot_data = tree.export_graphviz(clf, out_file=None,
feature_names=cancer.feature_names,
class_names=cancer.target_names,
filled=True, rounded=True,
special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %%
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
print("Важности признаков:\n{}".format(tree.feature_importances_))
# Out:
# Важности признаков:
# [0.00501731 0.         0.         0.         0.         0.
#  0.         0.03533434 0.0080277  0.         0.         0.
#  0.         0.01600893 0.00188491 0.01427147 0.02150277 0.
#  0.         0.0080277  0.         0.04170238 0.69546322 0.00493953
#  0.         0.         0.00980366 0.12941498 0.         0.00860111]

# %%
for name, score in zip(cancer["feature_names"], tree.feature_importances_):
    print(name, score)
# Out:
# mean radius 0.0050173132640802766
# mean texture 0.0
# mean perimeter 0.0
# mean area 0.0
# mean smoothness 0.0
# mean compactness 0.0
# mean concavity 0.0
# mean concave points 0.03533434312718254
# mean symmetry 0.00802770122252844
# mean fractal dimension 0.0
# radius error 0.0
# texture error 0.0
# perimeter error 0.0
# area error 0.016008931603369594
# smoothness error 0.0018849056123050926
# compactness error 0.014271468840050566
# concavity error 0.021502771131772614
# concave points error 0.0
# symmetry error 0.0
# fractal dimension error 0.00802770122252844
# worst radius 0.0
# worst texture 0.0417023759542683
# worst perimeter 0.6954632181471273
# worst area 0.004939525461536395
# worst smoothness 0.0
# worst compactness 0.0
# worst concavity 0.009803656591376428
# worst concave points 0.1294149793691649
# worst symmetry 0.0
# worst fractal dimension 0.008601108452709049

# %%
def plot_feature_importances_cancer(model):
    n_features = cancer.data.shape[1]
    plt.barh(range(n_features), model.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), cancer.feature_names)
    plt.xlabel("Важность признака")
    plt.ylabel("Признак")

plot_feature_importances_cancer(tree)

# %%
tree = mglearn.plots.plot_tree_not_monotone()
display(tree)
# Out:
# Feature importances: [0. 1.]

# %%
import pandas as pd
ram_prices = pd.read_csv("C:/Data/ram_price.csv")

plt.semilogy(ram_prices.date, ram_prices.price)
plt.xlabel("Год")
plt.ylabel("Цена $/Мбайт")
# Out:
# Text(0, 0.5, 'Цена $/Мбайт')

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression

data_train = ram_prices[ram_prices.date < 2000]
data_test = ram_prices[ram_prices.date >= 2000]

X_train = data_train.date[:, np.newaxis]
y_train = np.log(data_train.price)

tree = DecisionTreeRegressor().fit(X_train, y_train)
linear_reg = LinearRegression().fit(X_train, y_train)

X_all = ram_prices.date[:, np.newaxis]

pred_tree = tree.predict(X_all)
pred_lr = linear_reg.predict(X_all)

price_tree = np.exp(pred_tree)
price_lr = np.exp(pred_lr)

# %%
plt.semilogy(data_train.date, data_train.price, label="Обучающие данные")
plt.semilogy(data_test.date, data_test.price, label="Тестовые данные")
plt.semilogy(ram_prices.date, price_tree, label="Прогнозы дерева")
plt.semilogy(ram_prices.date, price_lr, label="Прогнозы линейной регрессии")
plt.legend()
